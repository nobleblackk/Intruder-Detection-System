# %%
import cv2
import os
import time
import numpy as np

# Load HAAR face classifier
face_classifier = cv2.CascadeClassifier('haarcascade_frontalface_default.xml')

# Load functions
fam=int(input("input"))
for i in range(fam):
    os.system("mkdir /root/new1/{}".format(i))
    time.sleep(10)
    def face_extractor(img):
        # Function detects faces and returns the cropped face
        # If no face detected, it returns the input image

        gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
        faces = face_classifier.detectMultiScale(gray, 1.3, 5)

        if faces is ():
            return None

        # Crop all faces found
        for (x,y,w,h) in faces:
            cropped_face = img[y:y+h, x:x+w]

        return cropped_face

    # Initialize Webcam
    cap = cv2.VideoCapture(0)
    count = 0

    # Collect 100 samples of your face from webcam input
    while True:

        ret, frame = cap.read()
        if face_extractor(frame) is not None:
            count += 1
            face = cv2.resize(face_extractor(frame), (200, 200))
            face = cv2.cvtColor(face, cv2.COLOR_BGR2GRAY)

            # Save file in specified directory with unique name
            file_name_path = '/root/new1/' + str(i) + '/face'  + str(count) + '.jpg'
            cv2.imwrite(file_name_path, face)

            # Put count on images and display live count
            cv2.putText(face, str(count), (50, 50), cv2.FONT_HERSHEY_COMPLEX, 1, (0,255,0), 2)
            cv2.imshow('Face Cropper', face)

        else:
            print("Face not found")
            pass

        if cv2.waitKey(1) == 13 or count == 100: #13 is the Enter Key
            break

    cap.release()
    cv2.destroyAllWindows()      
print("Collecting Samples Complete")

# %%
import cv2
import pyttsx3
import speech_recognition as sr

# %%
cv2.face_LBPHFaceRecognizer

# %%
# pip install  opencv-contrib-python

import cv2
import numpy as np
from os import listdir
from os.path import isfile, join
print(cv2.__version__)

abhi_model=[0 for i in range(fam)]

for i in range(fam):

    # Get the training data we previously made
    data_path = '/root/new1/' + str(i) + '/'
    print(data_path)
    #a=listdir('d:/faces')
    #print(a)
    # 
    onlyfiles = [f for f in listdir(data_path) if isfile(join(data_path, f))]
    print(onlyfiles)
    # Create arrays for training data and labels
    Training_Data, Labels = [], []

    # Open training images in our datapath
    # Create a numpy array for training data
    for j, files in enumerate(onlyfiles):
        image_path = data_path + onlyfiles[j]
        print(image_path)
        images = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)
        Training_Data.append(np.asarray(images, dtype=np.uint8))
        Labels.append(j)
    # 
    # Create a numpy array for both training data and labels
    Labels = np.asarray(Labels, dtype=np.int32)

    #globals() ['abhi_model{}'.format(i)]=cv2.face_LBPHFaceRecognizer.create()
    abhi_model[i]=cv2.face_LBPHFaceRecognizer.create()
    # Initialize facial recognizer
    # model = cv2.face_LBPHFaceRecognizer.create()
    # model=cv2.f
    # NOTE: For OpenCV 3.0 use cv2.face.createLBPHFaceRecognizer()

    # Let's train our model 
    abhi_model[i].train(np.asarray(Training_Data), np.asarray(Labels))
    type(abhi_model[i])
    #print(abhi_model[i])
print("Model trained sucessefully")

# %%
import cv2
import numpy as np
import webbrowser
import subprocess as sp
import pyttsx3
import speech_recognition as sr


face_classifier = cv2.CascadeClassifier('haarcascade_frontalface_default.xml')

def face_detector(img, size=0.5):
    
    # Convert image to grayscale
    gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
    faces = face_classifier.detectMultiScale(gray, 1.3, 5)
    if faces is ():
        return img, []
    
    for (x,y,w,h) in faces:
        cv2.rectangle(img,(x,y),(x+w,y+h),(0,255,255),2)
        roi = img[y:y+h, x:x+w]
        roi = cv2.resize(roi, (200, 200))
    return img, roi


# Open Webcam
cap = cv2.VideoCapture(0)
results=[]

while True:

    ret, frame = cap.read()
    
    image, face = face_detector(frame)
    
    try:
        face = cv2.cvtColor(face, cv2.COLOR_BGR2GRAY)

        # Pass face to prediction model
        # "results" comprises of a tuple containing the label and the confidence value
        for i in range(fam):
            #results = vimal_model.predict(face)
            a=globals() ['abhi_model{}'.format(i)]
            results.append(a)
        print(results)
        for i in range(fam):
            if results[i][1] < 500:
                confidence = int( 100 * (1 - (results[i][1])/400) )
                break    
        display_string = str(confidence) + '% Confident it is User'
            
        cv2.putText(image, display_string, (100, 120), cv2.FONT_HERSHEY_COMPLEX, 1, (255,120,150), 2)
        
        if confidence > 85:
            cv2.putText(image, "Hey Vimal", (250, 450), cv2.FONT_HERSHEY_COMPLEX, 1, (0,255,0), 2)
            cv2.imshow('Face Recognition', image )
            #sp.getoutput("usermod -U harry")
                       
        else:
            #cv2.putText(image, "i dont rec U", (250, 450), cv2.FONT_HERSHEY_COMPLEX, 1, (0,0,255), 2)
            #cv2.imshow('Face Recognition', image )
            #def face_extractor(img):
            # Function detects faces and returns the cropped face
            # If no face detected, it returns the input image

            #gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
            #faces = face_classifier.detectMultiScale(gray, 1.3, 5)

            #if faces is ():
            #speaker=pyttsx3.init()
            #speaker.say("this")
            #speaker.runAndWait()
            #count=0
            #for i in range(5):
             #   count+=1
              #  name='/root/theft/face' + str(count) + '.jpg'
               # cv2.imwrite(name,frame)
            #break   

    except:
        cv2.putText(image, "No Face Found", (220, 120) , cv2.FONT_HERSHEY_COMPLEX, 1, (0,0,255), 2)
        cv2.putText(image, "Locked", (250, 450), cv2.FONT_HERSHEY_COMPLEX, 1, (0,0,255), 2)
        cv2.imshow('Face Recognition', image )
        pass
        
    if cv2.waitKey(1) == 13: #13 is the Enter Key
        break
        
cap.release()
cv2.destroyAllWindows()

# %%
import cv2
import pyttsx3
import numpy as np
import webbrowser
import subprocess as sp
import os

speaker=pyttsx3.init()

face_classifier = cv2.CascadeClassifier('haarcascade_frontalface_default.xml')

def face_detector(img, size=0.5):
    
    # Convert image to grayscale
    gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
    faces = face_classifier.detectMultiScale(gray, 1.3, 5)
    if faces is ():
        return img, []
    
    for (x,y,w,h) in faces:
        cv2.rectangle(img,(x,y),(x+w,y+h),(0,255,255),2)
        roi = img[y:y+h, x:x+w]
        roi = cv2.resize(roi, (200, 200))
    return img, roi


# Open Webcam
cap = cv2.VideoCapture(0)

results=[0 for i in range(fam)]
confidence=[0 for i in range(fam)]
display_string=[0 for i in range(fam)]
temp=0

while True:

    ret, frame = cap.read()
    
    image, face = face_detector(frame)
    
    try:
        face = cv2.cvtColor(face, cv2.COLOR_BGR2GRAY)

        # Pass face to prediction model
        # "results" comprises of a tuple containing the label and the confidence value
        for i in range(fam):
            results[i] = abhi_model[i].predict(face)
            #print(results[i])
            if results[i][1] < 500:
                confidence[i] = int( 100 * (1 - (results[i][1])/400) )
                display_string[i] = str(confidence[i]) + '% Confident it is User'
                #print("this is results{}".format(i))
                if confidence[i] < 85:
                    #temp=1
                    #temp1=i
                    #break
                    speaker.say("this")
                    speaker.runAndWait()
                
        cv2.putText(image, display_string[temp1], (100, 120), cv2.FONT_HERSHEY_COMPLEX, 1, (255,120,150), 2)
            
        '''if temp==1:
                #cv2.putText(image, display_string[i], (100, 120), cv2.FONT_HERSHEY_COMPLEX, 1, (255,120,150), 2)
            cv2.putText(image, "Hey Vimal", (250, 450), cv2.FONT_HERSHEY_COMPLEX, 1, (0,255,0), 2)
            cv2.imshow('Face Recognition', image )
    
        else:
            cv2.putText(image, "i dont rec U", (250, 450), cv2.FONT_HERSHEY_COMPLEX, 1, (0,0,255), 2)
            cv2.imshow('Face Recognition', image )
            os.system("mkdir /root/Desktop/theft")'''

    except:
        cv2.putText(image, "No Face Found", (220, 120) , cv2.FONT_HERSHEY_COMPLEX, 1, (0,0,255), 2)
        cv2.putText(image, "Locked", (250, 450), cv2.FONT_HERSHEY_COMPLEX, 1, (0,0,255), 2)
        cv2.imshow('Face Recognition', image )
        pass
        
    if cv2.waitKey(1) == 13: #13 is the Enter Key
        break
        
cap.release()
cv2.destroyAllWindows()
